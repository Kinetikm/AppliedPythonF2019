# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
data = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep='|')
data
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# 5          6   42      M      executive    98101
# 6          7   57      M  administrator    91344
# 7          8   36      M  administrator    05201
# 8          9   29      M        student    01002
# 9         10   53      M         lawyer    90703
# 10        11   39      F          other    30329
# 11        12   28      F          other    06405
# 12        13   47      M       educator    29206
# 13        14   45      M      scientist    55106
# 14        15   49      F       educator    97301
# 15        16   21      M  entertainment    10309
# 16        17   30      M     programmer    06355
# 17        18   35      F          other    37212
# ...

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
data.groupby('occupation').age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
temp = data.copy(deep=True)
temp = data.pivot_table(index='occupation', columns='gender', aggfunc='size', fill_value=0)
sums = temp[['F', 'M']].sum(axis=1)
temp['MaleRatio'] = temp['M'] / sums
print(temp.sort_values(by='MaleRatio', ascending=False))
# Out:
# gender          F    M  MaleRatio
# occupation
# doctor          0    7   1.000000
# engineer        2   65   0.970149
# technician      1   26   0.962963
# retired         1   13   0.928571
# programmer      6   60   0.909091
# executive       3   29   0.906250
# scientist       3   28   0.903226
# entertainment   2   16   0.888889
# lawyer          2   10   0.833333
# salesman        3    9   0.750000
# educator       26   69   0.726316
# student        60  136   0.693878
# other          36   69   0.657143
# marketing      10   16   0.615385
# writer         19   26   0.577778
# none            4    5   0.555556
# administrator  36   43   0.544304
# artist         13   15   0.535714
# librarian      29   22   0.431373
# healthcare     11    5   0.312500
# homemaker       6    1   0.142857

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
age_sep = pd.concat([data.groupby('occupation').age.min(), data.groupby('occupation').age.max()], axis=1)
age_sep.columns = ['min_age','max_age']
age_sep
# Out:
#                min_age  max_age
# occupation
# administrator       21       70
# artist              19       48
# doctor              28       64
# educator            23       63
# engineer            22       70
# entertainment       15       50
# executive           22       69
# healthcare          22       62
# homemaker           20       50
# lawyer              21       53
# librarian           23       69
# marketing           24       55
# none                11       55
# other               13       64
# programmer          20       63
# retired             51       73
# salesman            18       66
# scientist           23       55
# student              7       42
# technician          21       55
# writer              18       60

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
data.groupby(['occupation', 'gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
tm = pd.concat([data[data.gender == 'M'].groupby('occupation').gender.count(), data[data.gender == 'F'].groupby('occupation').gender.count()], axis=1, sort=False)
tm.columns = ['M','F']
print(tm)
tm['F'].replace(np.nan, 0, inplace = True)
print(tm)
tm['percentage_of_women'] = tm.loc[:,'F'] / (tm.loc[:,'M'] + tm.loc[:,'F']) * 100
tm['percentage_of_men'] = tm.loc[:,'M'] / (tm.loc[:,'M'] + tm.loc[:,'F']) * 100
#tm.drop(columns=['1','2'], inplace=True)
tm
# Out:
#                  M     F
# administrator   43  36.0
# artist          15  13.0
# doctor           7   NaN
# educator        69  26.0
# engineer        65   2.0
# entertainment   16   2.0
# executive       29   3.0
# healthcare       5  11.0
# homemaker        1   6.0
# lawyer          10   2.0
# librarian       22  29.0
# marketing       16  10.0
# none             5   4.0
# other           69  36.0
# programmer      60   6.0
# retired         13   1.0
# salesman         9   3.0
# scientist       28   3.0
# student        136  60.0
# technician      26   1.0
# writer          26  19.0
#                  M     F
# administrator   43  36.0
# artist          15  13.0
# doctor           7   0.0
# educator        69  26.0
# engineer        65   2.0
# entertainment   16   2.0
# executive       29   3.0
# healthcare       5  11.0
# homemaker        1   6.0
# lawyer          10   2.0
# librarian       22  29.0
# marketing       16  10.0
# none             5   4.0
# other           69  36.0
# ...
