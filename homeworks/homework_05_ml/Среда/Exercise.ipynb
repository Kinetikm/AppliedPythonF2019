# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
users = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user", sep="|", 
                    index_col="user_id")

# %%
users.head()
# Out:
#          age gender  occupation zip_code
# user_id
# 1         24      M  technician    85711
# 2         53      F       other    94043
# 3         23      M      writer    32067
# 4         24      M  technician    43537
# 5         33      F       other    15213

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
users.groupby("occupation")["age"].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
grouped = users.groupby("occupation").gender.value_counts(normalize=True)
grouped = pd.DataFrame(grouped.reset_index(name = "ratio"))
grouped[grouped["gender"]=="M"].sort_values("ratio", ascending=0)
# Out:
#        occupation gender     ratio
# 4          doctor      M  1.000000
# 7        engineer      M  0.970149
# 37     technician      M  0.962963
# 29        retired      M  0.928571
# 27     programmer      M  0.909091
# 11      executive      M  0.906250
# 33      scientist      M  0.903226
# 9   entertainment      M  0.888889
# 17         lawyer      M  0.833333
# 31       salesman      M  0.750000
# 5        educator      M  0.726316
# 35        student      M  0.693878
# 25          other      M  0.657143
# 21      marketing      M  0.615385
# 39         writer      M  0.577778
# 23           none      M  0.555556
# 0   administrator      M  0.544304
# 2          artist      M  0.535714
# 20      librarian      M  0.431373
# 14     healthcare      M  0.312500
# 16      homemaker      M  0.142857

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
users.groupby("occupation").age.agg([min, max])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
users.groupby(["occupation", "gender"]).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
percentage = lambda x: x * 100
df = pd.DataFrame(users.groupby("occupation").gender.value_counts(normalize=True).reset_index(name="percent"))
df["percent"] = df["percent"].apply(percentage)
df
# Out:
#        occupation gender     percent
# 0   administrator      M   54.430380
# 1   administrator      F   45.569620
# 2          artist      M   53.571429
# 3          artist      F   46.428571
# 4          doctor      M  100.000000
# 5        educator      M   72.631579
# 6        educator      F   27.368421
# 7        engineer      M   97.014925
# 8        engineer      F    2.985075
# 9   entertainment      M   88.888889
# 10  entertainment      F   11.111111
# 11      executive      M   90.625000
# 12      executive      F    9.375000
# 13     healthcare      F   68.750000
# 14     healthcare      M   31.250000
# 15      homemaker      F   85.714286
# 16      homemaker      M   14.285714
# 17         lawyer      M   83.333333
# 18         lawyer      F   16.666667
# 19      librarian      F   56.862745
# 20      librarian      M   43.137255
# 21      marketing      M   61.538462
# 22      marketing      F   38.461538
# 23           none      M   55.555556
# ...
