# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
called_users = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user", sep="|")
called_users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
called_users.groupby("occupation").age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
called_users.loc[called_users['gender'] == 'M'].groupby('occupation').gender.count().sort_values(ascending=False)
# Out:
# occupation
# student          136
# educator          69
# other             69
# engineer          65
# programmer        60
# administrator     43
# executive         29
# scientist         28
# technician        26
# writer            26
# librarian         22
# marketing         16
# entertainment     16
# artist            15
# retired           13
# lawyer            10
# salesman           9
# doctor             7
# healthcare         5
# none               5
# homemaker          1
# Name: gender, dtype: int64

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
called_users.groupby('occupation').age.describe()[['min', 'max']]
# Out:
#                 min   max
# occupation
# administrator  21.0  70.0
# artist         19.0  48.0
# doctor         28.0  64.0
# educator       23.0  63.0
# engineer       22.0  70.0
# entertainment  15.0  50.0
# executive      22.0  69.0
# healthcare     22.0  62.0
# homemaker      20.0  50.0
# lawyer         21.0  53.0
# librarian      23.0  69.0
# marketing      24.0  55.0
# none           11.0  55.0
# other          13.0  64.0
# programmer     20.0  63.0
# retired        51.0  73.0
# salesman       18.0  66.0
# scientist      23.0  55.0
# student         7.0  42.0
# technician     21.0  55.0
# writer         18.0  60.0

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
called_users.groupby(['occupation', 'gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
pd.crosstab(called_users["occupation"], called_users["gender"], normalize="index") * 100
# Out:
# gender                 F           M
# occupation
# administrator  45.569620   54.430380
# artist         46.428571   53.571429
# doctor          0.000000  100.000000
# educator       27.368421   72.631579
# engineer        2.985075   97.014925
# entertainment  11.111111   88.888889
# executive       9.375000   90.625000
# healthcare     68.750000   31.250000
# homemaker      85.714286   14.285714
# lawyer         16.666667   83.333333
# librarian      56.862745   43.137255
# marketing      38.461538   61.538462
# none           44.444444   55.555556
# other          34.285714   65.714286
# programmer      9.090909   90.909091
# retired         7.142857   92.857143
# salesman       25.000000   75.000000
# scientist       9.677419   90.322581
# student        30.612245   69.387755
# technician      3.703704   96.296296
# writer         42.222222   57.777778
