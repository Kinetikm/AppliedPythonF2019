# %% [markdown]
# # Welcome to Jupyter!

# %%
import pandas as pd
import numpy as np

# %%
citizens = pd.read_csv('.//adult.data', sep = ',')

# %% [markdown]
# ## 1. How many males and females are there?

# %%
citizens.groupby(' Male').size()
citizens.head()
# Out:
#        39          State-gov   77516      Bachelors   13  \
# 0      50   Self-emp-not-inc   83311      Bachelors   13
# 1      38            Private  215646        HS-grad    9
# 2      53            Private  234721           11th    7
# 3      28            Private  338409      Bachelors   13
# 4      37            Private  284582        Masters   14
# 5      49            Private  160187            9th    5
# 6      52   Self-emp-not-inc  209642        HS-grad    9
# 7      31            Private   45781        Masters   14
# 8      42            Private  159449      Bachelors   13
# 9      37            Private  280464   Some-college   10
# 10     30          State-gov  141297      Bachelors   13
# 11     23            Private  122272      Bachelors   13
# 12     32            Private  205019     Assoc-acdm   12
# 13     40            Private  121772      Assoc-voc   11
# 14     34            Private  245487        7th-8th    4
# ...

# %% [markdown]
# ## 2. What is the mean male age?

# %%
citizens[citizens[' Male'] == ' Male']['39'].mean()
# Out:
# 39.433567396392675

# %% [markdown]
# ## 3. What is the proportion of the US citizens?

# %%
float(len(citizens[citizens[' United-States'] == ' United-States']))/float(len(citizens))
# Out:
# 0.8958538083538083

# %% [markdown]
# # # 5. What is the mean and standard deviation of the ”final weight” for divorced people?

# %%
print(citizens[citizens[' Never-married']==' Divorced'][' 77516'].mean())
print(citizens[citizens[' Never-married']==' Divorced'][' 77516'].std())
# Out:
# 185802.79045689848
# 105646.78945933598

# %% [markdown]
# ## 6. Is it true that the people who receive over 50k are mostly highly educated?

# %%
citizens[citizens[' <=50K'] == ' >50K'][' Bachelors'].value_counts()
# Out:
#  Bachelors       2221
#  HS-grad         1675
#  Some-college    1387
#  Masters          959
#  Prof-school      423
#  Assoc-voc        361
#  Doctorate        306
#  Assoc-acdm       265
#  10th              62
#  11th              60
#  7th-8th           40
#  12th              33
#  9th               27
#  5th-6th           16
#  1st-4th            6
# Name:  Bachelors, dtype: int64

# %% [markdown]
# # # 7. What is the maximum male and female age for each race?

# %%
citizens.groupby([' White', ' Male'])['39'].max()
# Out:
#  White                Male
#  Amer-Indian-Eskimo   Female    80
#                       Male      82
#  Asian-Pac-Islander   Female    75
#                       Male      90
#  Black                Female    90
#                       Male      90
#  Other                Female    74
#                       Male      77
#  White                Female    90
#                       Male      90
# Name: 39, dtype: int64

# %% [markdown]
# # #  8. The people from which countries work as farmers/fishers?

# %%
citizens[citizens[' Adm-clerical'] == ' Farming-fishing'][' United-States'].value_counts()
# Out:
#  United-States    879
#  Mexico            77
#  Puerto-Rico        5
#  ?                  5
#  Philippines        4
#  Guatemala          4
#  Cuba               2
#  Italy              2
#  El-Salvador        2
#  Canada             2
#  Vietnam            2
#  Germany            1
#  Poland             1
#  Ireland            1
#  Cambodia           1
#  England            1
#  Yugoslavia         1
#  Japan              1
#  Hong               1
#  France             1
#  Portugal           1
# Name:  United-States, dtype: int64

# %% [markdown]
# # #  9. Consider the ratio of the number of 1) male bachelors to male masters, and 2) female bachelors to female masters. Which one is higher?

# %%
float(citizens[(citizens[' Bachelors'] == ' Bachelors') & (citizens[' Male'] == ' Male')].shape[0])/float(citizens[(citizens[' Bachelors'] == ' Masters') & (citizens[' Male'] == ' Male')].shape[0])
# Out:
# 3.146588037068239

# %%
float(citizens[(citizens[' Bachelors'] == ' Bachelors') & (citizens[' Male'] == ' Female')].shape[0])/float(citizens[(citizens[' Bachelors'] == ' Masters') & (citizens[' Male'] == ' Female')].shape[0])
# Out:
# 3.0205223880597014

# %% [markdown]
# # # 10. What is the largest number of hours a person works a week? How many people who work this number of hours are there? What is their income?

# %%
citizens[' 40'].max()
# max hours
# Out:
# 99

# %%
len(citizens[citizens[' 40'] == citizens[' 40'].max()])
#amount of people
# Out:
# 85

# %%
citizens[citizens[' 40'] == citizens[' 40'].max()][' <=50K']
#their income
# Out:
# 934        >50K
# 1171       >50K
# 1886       >50K
# 3577       >50K
# 4085      <=50K
# 4307      <=50K
# 4440       >50K
# 5375      <=50K
# 5431      <=50K
# 6617      <=50K
# 6897      <=50K
# 8071      <=50K
# 8392       >50K
# 8653      <=50K
# 8795       >50K
# 9810      <=50K
# 9830      <=50K
# 10142     <=50K
# 10265     <=50K
# 10467     <=50K
# 10985      >50K
# 11832     <=50K
# 12208     <=50K
# 12624     <=50K
# 12787     <=50K
# 13557      >50K
# 13579     <=50K
# 13616     <=50K
# 13857      >50K
# 14592     <=50K
#           ...
# 23225     <=50K
# 23397     <=50K
# 23648      >50K
# 23829     <=50K
# 24482      >50K
# 25353     <=50K
# 25712      >50K
# 25805     <=50K
# 25830      >50K
# 25985     <=50K
# 26249     <=50K
# 26595      >50K
# 26637     <=50K
# 26857     <=50K
# 27221     <=50K
# 27763     <=50K
# 27808     <=50K
# 28111     <=50K
# 29186      >50K
# 29750     <=50K
# 29988      >50K
# 30035      >50K
# 30609      >50K
# 30753     <=50K
# ...
